# %%
import pandas as pd
df1=pd.read_csv("healthcare-dataset-stroke-data.csv")
df2=pd.read_csv("stroke-train.csv")
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df2.head()
# Out:
#    id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0   0    Male  28.0             0              0          Yes   Private
# 1   1    Male  33.0             0              0          Yes   Private
# 2   2  Female  42.0             0              0          Yes   Private
# 3   3    Male  56.0             0              0          Yes   Private
# 4   4  Female  24.0             0              0           No   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              79.53  31.1     never smoked       0
# 1          Rural              78.44  23.9  formerly smoked       0
# 2          Rural             103.00  40.3          Unknown       0
# 3          Urban              64.87  28.8     never smoked       0
# 4          Rural              73.36  28.8     never smoked       0

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.shape
# Out:
# (20414, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20414 entries, 0 to 20413
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20414 non-null  int64
#  1   gender             20414 non-null  object
#  2   age                20414 non-null  float64
#  3   hypertension       20414 non-null  int64
#  4   heart_disease      20414 non-null  int64
#  5   ever_married       20414 non-null  object
#  6   work_type          20414 non-null  object
#  7   Residence_type     20414 non-null  object
#  8   avg_glucose_level  20414 non-null  float64
#  9   bmi                20213 non-null  float64
#  10  smoking_status     20414 non-null  object
#  11  stroke             20414 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 1.9+ MB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.drop("id",axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df["hypertension"].value_counts()
# Out:
# 0    19155
# 1     1259
# Name: hypertension, dtype: int64

# %%
df["heart_disease"].value_counts()
# Out:
# 0    19781
# 1      633
# Name: heart_disease, dtype: int64

# %%
df["ever_married"].value_counts()
# Out:
# Yes    13738
# No      6676
# Name: ever_married, dtype: int64

# %%
df["work_type"].value_counts()
# Out:
# Private          12677
# Self-employed     2758
# children          2725
# Govt_job          2190
# Never_worked        64
# Name: work_type, dtype: int64

# %%
df["Residence_type"].value_counts()
# Out:
# Urban    10236
# Rural    10178
# Name: Residence_type, dtype: int64

# %%
df["smoking_status"].value_counts()
# Out:
# never smoked       8173
# Unknown            6087
# formerly smoked    3222
# smokes             2932
# Name: smoking_status, dtype: int64

# %%
df= df.dropna(axis=0)

# %%
df.shape
# Out:
# (20213, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20213 entries, 0 to 20413
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             20213 non-null  object
#  1   age                20213 non-null  float64
#  2   hypertension       20213 non-null  int64
#  3   heart_disease      20213 non-null  int64
#  4   ever_married       20213 non-null  object
#  5   work_type          20213 non-null  object
#  6   Residence_type     20213 non-null  object
#  7   avg_glucose_level  20213 non-null  float64
#  8   bmi                20213 non-null  float64
#  9   smoking_status     20213 non-null  object
#  10  stroke             20213 non-null  int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 1.9+ MB

# %%
dms=pd.get_dummies(df[["gender","hypertension","heart_disease","ever_married","work_type","Residence_type","smoking_status"]])
y=df["stroke"]
x_=df.drop(["gender","hypertension","heart_disease","ever_married","work_type","Residence_type","smoking_status"],axis=1).astype("float64")

# %%
y.head()
# Out:
# 0    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: stroke, dtype: int64

# %%
dms.head()
# Out:
#    hypertension  heart_disease  gender_Female  gender_Male  gender_Other  \
# 0             0              1              0            1             0
# 2             0              1              0            1             0
# 3             0              0              1            0             0
# 4             1              0              1            0             0
# 5             0              0              0            1             0
#
#    ever_married_No  ever_married_Yes  work_type_Govt_job  \
# 0                0                 1                   0
# 2                0                 1                   0
# 3                0                 1                   0
# 4                0                 1                   0
# 5                0                 1                   0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# ...

# %%
x_.head()
# Out:
#     age  avg_glucose_level   bmi  stroke
# 0  67.0             228.69  36.6     1.0
# 2  80.0             105.92  32.5     1.0
# 3  49.0             171.23  34.4     1.0
# 4  79.0             174.12  24.0     1.0
# 5  81.0             186.21  29.0     1.0

# %%
x_=x_.drop(["stroke"],axis=1)

# %%
x_.head()
# Out:
#     age  avg_glucose_level   bmi
# 0  67.0             228.69  36.6
# 2  80.0             105.92  32.5
# 3  49.0             171.23  34.4
# 4  79.0             174.12  24.0
# 5  81.0             186.21  29.0

# %%
x=pd.concat([x_,dms],axis=1)

# %%
x.head()
# Out:
#     age  avg_glucose_level   bmi  hypertension  heart_disease  gender_Female  \
# 0  67.0             228.69  36.6             0              1              0
# 2  80.0             105.92  32.5             0              1              0
# 3  49.0             171.23  34.4             0              0              1
# 4  79.0             174.12  24.0             1              0              1
# 5  81.0             186.21  29.0             0              0              0
#
#    gender_Male  gender_Other  ever_married_No  ever_married_Yes  ...  \
# 0            1             0                0                 1  ...
# 2            1             0                0                 1  ...
# 3            0             0                0                 1  ...
# 4            0             0                0                 1  ...
# 5            1             0                0                 1  ...
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# ...

# %%
#ElasticNet
from sklearn.linear_model import ElasticNetCV
model = ElasticNetCV(cv=10).fit(x,y)

# %%
test_df=pd.read_csv("stroke-test.csv")

# %%
test_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0  15304  Female  57.0             0              0          Yes   Private
# 1  15305    Male  70.0             1              0          Yes   Private
# 2  15306  Female   5.0             0              0           No  children
# 3  15307  Female  56.0             0              0          Yes  Govt_job
# 4  15308    Male  32.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi smoking_status
# 0          Rural              82.54  33.4        Unknown
# 1          Urban              72.06  28.5        Unknown
# 2          Urban             103.72  19.5        Unknown
# 3          Urban              69.24  41.4         smokes
# 4          Rural             111.15  30.1         smokes

# %%
test_df.index=test_df["id"]

# %%
test_df.head()
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# id
# 15304  15304  Female  57.0             0              0          Yes
# 15305  15305    Male  70.0             1              0          Yes
# 15306  15306  Female   5.0             0              0           No
# 15307  15307  Female  56.0             0              0          Yes
# 15308  15308    Male  32.0             0              0          Yes
#
#       work_type Residence_type  avg_glucose_level   bmi smoking_status
# id
# 15304   Private          Rural              82.54  33.4        Unknown
# 15305   Private          Urban              72.06  28.5        Unknown
# 15306  children          Urban             103.72  19.5        Unknown
# 15307  Govt_job          Urban              69.24  41.4         smokes
# 15308   Private          Rural             111.15  30.1         smokes

# %%
test_df.drop("id",axis=1,inplace=True)

# %%
test_df["hypertension"].value_counts()
# Out:
# 0    9679
# 1     525
# Name: hypertension, dtype: int64

# %%
test_df["heart_disease"].value_counts()
# Out:
# 0    9982
# 1     222
# Name: heart_disease, dtype: int64

# %%
test_df["ever_married"].value_counts()
# Out:
# Yes    7073
# No     3131
# Name: ever_married, dtype: int64

# %%
test_df["work_type"].value_counts()
# Out:
# Private          6573
# Self-employed    1349
# children         1270
# Govt_job          992
# Never_worked       20
# Name: work_type, dtype: int64

# %%
test_df["Residence_type"].value_counts()
# Out:
# Urban    5182
# Rural    5022
# Name: Residence_type, dtype: int64

# %%
test_df["smoking_status"].value_counts()
# Out:
# never smoked       4237
# Unknown            2976
# formerly smoked    1584
# smokes             1407
# Name: smoking_status, dtype: int64

# %%
test_dms=pd.get_dummies(test_df[["gender","hypertension","heart_disease","ever_married","work_type","Residence_type","smoking_status"]])

# %%
test_x_=test_df.drop(["gender","hypertension","heart_disease","ever_married","work_type","Residence_type","smoking_status"],axis=1).astype("float64")

# %%
test_x=pd.concat([test_x_,test_dms],axis=1)

# %%
test_x.head()
# Out:
#         age  avg_glucose_level   bmi  hypertension  heart_disease  \
# id
# 15304  57.0              82.54  33.4             0              0
# 15305  70.0              72.06  28.5             1              0
# 15306   5.0             103.72  19.5             0              0
# 15307  56.0              69.24  41.4             0              0
# 15308  32.0             111.15  30.1             0              0
#
#        gender_Female  gender_Male  gender_Other  ever_married_No  \
# id
# 15304              1            0             0                0
# 15305              0            1             0                0
# 15306              1            0             0                1
# 15307              1            0             0                0
# 15308              0            1             0                0
#
#        ever_married_Yes  ...  work_type_Never_worked  work_type_Private  \
# id                       ...
# ...

# %%
model.predict(test_x)
# Out:
# array([ 0.06160306,  0.13468181, -0.00392047, ..., -0.00929095,
#        -0.01790527, -0.02111885])

# %%
predictions=model.predict(test_x)

# %%
test_df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# id
# 15304  Female  57.0             0              0          Yes   Private
# 15305    Male  70.0             1              0          Yes   Private
# 15306  Female   5.0             0              0           No  children
# 15307  Female  56.0             0              0          Yes  Govt_job
# 15308    Male  32.0             0              0          Yes   Private
#
#       Residence_type  avg_glucose_level   bmi smoking_status
# id
# 15304          Rural              82.54  33.4        Unknown
# 15305          Urban              72.06  28.5        Unknown
# 15306          Urban             103.72  19.5        Unknown
# 15307          Urban              69.24  41.4         smokes
# 15308          Rural             111.15  30.1         smokes

# %%
test_df["stroke"]=predictions
submission_df=test_df.drop(columns=["gender","age","hypertension","heart_disease","ever_married","work_type","Residence_type","avg_glucose_level","bmi","smoking_status"],axis=1)

# %%
submission_df.head()
# Out:
#          stroke
# id
# 15304  0.061603
# 15305  0.134682
# 15306 -0.003920
# 15307  0.046081
# 15308  0.001489

# %%
submission_df.to_csv("stroke-best-submission_df.csv")
